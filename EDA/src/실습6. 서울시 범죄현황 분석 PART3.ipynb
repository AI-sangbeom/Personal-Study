# %% [markdown]
# # 연도별 환황 분석

# %% [markdown]
# ## Glob 모듈

# %%
from glob import glob

glob('./../data/data/*')
# Out:
# ['./../data/data/2006년.csv',
#  './../data/data/2008년.csv',
#  './../data/data/2009년.csv',
#  './../data/data/2014년.csv',
#  './../data/data/2002년.csv',
#  './../data/data/02. US_Unemployment_Oct2012.csv',
#  './../data/data/2001년.csv',
#  './../data/data/2011년.csv',
#  './../data/data/2016년.csv',
#  './../data/data/2007년.csv',
#  './../data/data/2015년.csv',
#  './../data/data/2003년.csv',
#  './../data/data/2019년.csv',
#  './../data/data/2017년.csv',
#  './../data/data/2018년.csv',
#  './../data/data/2000년.csv',
#  './../data/data/2004년.csv',
#  './../data/data/seoul_crime_result.csv',
#  './../data/data/2010년.csv',
#  './../data/data/2012년.csv',
#  './../data/data/2013년.csv',
#  './../data/data/2005년.csv']

# %%
target_path = './../data/data'
file_list = glob(target_path + '/20*.csv')
file_list
# Out:
# ['./../data/data/2006년.csv',
#  './../data/data/2008년.csv',
#  './../data/data/2009년.csv',
#  './../data/data/2014년.csv',
#  './../data/data/2002년.csv',
#  './../data/data/2001년.csv',
#  './../data/data/2011년.csv',
#  './../data/data/2016년.csv',
#  './../data/data/2007년.csv',
#  './../data/data/2015년.csv',
#  './../data/data/2003년.csv',
#  './../data/data/2019년.csv',
#  './../data/data/2017년.csv',
#  './../data/data/2018년.csv',
#  './../data/data/2000년.csv',
#  './../data/data/2004년.csv',
#  './../data/data/2010년.csv',
#  './../data/data/2012년.csv',
#  './../data/data/2013년.csv',
#  './../data/data/2005년.csv']

# %%
for each_file in file_list:
    print(each_file)
# Out:
# ./../data/data/2006년.csv
# ./../data/data/2008년.csv
# ./../data/data/2009년.csv
# ./../data/data/2014년.csv
# ./../data/data/2002년.csv
# ./../data/data/2001년.csv
# ./../data/data/2011년.csv
# ./../data/data/2016년.csv
# ./../data/data/2007년.csv
# ./../data/data/2015년.csv
# ./../data/data/2003년.csv
# ./../data/data/2019년.csv
# ./../data/data/2017년.csv
# ./../data/data/2018년.csv
# ./../data/data/2000년.csv
# ./../data/data/2004년.csv
# ./../data/data/2010년.csv
# ./../data/data/2012년.csv
# ./../data/data/2013년.csv
# ./../data/data/2005년.csv

# %%
import pandas as pd
import numpy as np

crime_raw_data = pd.read_csv(file_list[0],
                              usecols=[0,1,2,3], encoding='euc-kr')

crime_station = crime_raw_data.pivot_table(
    crime_raw_data, index=['구분'], columns=['죄종', '발생검거'], aggfunc=[np.sum] 
)

crime_station.columns = ['강간검거', '강간', '강도검거', '강도', '살인검거',
                         '살인', '절도검거', '절도', '폭력검거','폭력']
crime_station['year'] = 2000
crime_station.head()
# Out:
# /tmp/ipykernel_107931/3349232950.py:7: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
#      강간검거     강간  강도검거    강도  살인검거    살인   절도검거      절도    폭력검거      폭력  year
# 구분
# 강남  124.0  168.0  33.0  65.0   6.0   5.0  461.0  1014.0  2666.0  2853.0  2000
# 강동  117.0  117.0  42.0  35.0   3.0   4.0  604.0   672.0  2574.0  2619.0  2000
# 강북   82.0   92.0  72.0  78.0   7.0   5.0  629.0   698.0  2416.0  2428.0  2000
# 강서  117.0  137.0  40.0  43.0  15.0  16.0  710.0  1267.0  3053.0  3186.0  2000
# 관악  129.0  236.0  44.0  63.0   4.0   5.0  663.0  1628.0  2960.0  3192.0  2000

# %%
for each_file in file_list:
    print(each_file.split('/'))
# Out:
# ['.', '..', 'data', 'data', '2006년.csv']
# ['.', '..', 'data', 'data', '2008년.csv']
# ['.', '..', 'data', 'data', '2009년.csv']
# ['.', '..', 'data', 'data', '2014년.csv']
# ['.', '..', 'data', 'data', '2002년.csv']
# ['.', '..', 'data', 'data', '2001년.csv']
# ['.', '..', 'data', 'data', '2011년.csv']
# ['.', '..', 'data', 'data', '2016년.csv']
# ['.', '..', 'data', 'data', '2007년.csv']
# ['.', '..', 'data', 'data', '2015년.csv']
# ['.', '..', 'data', 'data', '2003년.csv']
# ['.', '..', 'data', 'data', '2019년.csv']
# ['.', '..', 'data', 'data', '2017년.csv']
# ['.', '..', 'data', 'data', '2018년.csv']
# ['.', '..', 'data', 'data', '2000년.csv']
# ['.', '..', 'data', 'data', '2004년.csv']
# ['.', '..', 'data', 'data', '2010년.csv']
# ['.', '..', 'data', 'data', '2012년.csv']
# ['.', '..', 'data', 'data', '2013년.csv']
# ['.', '..', 'data', 'data', '2005년.csv']

# %%
for each_file in file_list:
    print(each_file.split('/')[-1])
# Out:
# 2006년.csv
# 2008년.csv
# 2009년.csv
# 2014년.csv
# 2002년.csv
# 2001년.csv
# 2011년.csv
# 2016년.csv
# 2007년.csv
# 2015년.csv
# 2003년.csv
# 2019년.csv
# 2017년.csv
# 2018년.csv
# 2000년.csv
# 2004년.csv
# 2010년.csv
# 2012년.csv
# 2013년.csv
# 2005년.csv

# %%
for each_file in file_list:
    print(each_file.split('/')[-1][:4])
# Out:
# 2006
# 2008
# 2009
# 2014
# 2002
# 2001
# 2011
# 2016
# 2007
# 2015
# 2003
# 2019
# 2017
# 2018
# 2000
# 2004
# 2010
# 2012
# 2013
# 2005

# %%
crime_station_t = []

for each_file in file_list:
    crime_raw_data = pd.read_csv(each_file, usecols=[0,1,2,3], encoding='euc-kr')
    crime_station = crime_raw_data.pivot_table(
        crime_raw_data, index=['구분'], columns=['죄종', '발생검거'], aggfunc=[np.sum]
    )
    crime_station.columns = ['강간검거', '강간', '강도검거', '강도', '살인검거',
                             '살인', '절도검거', '절도', '폭력머거', '폭력']
    crime_station['year'] = each_file.split('/')[-1][:4]

    crime_station.reset_index(inplace=True)
    crime_station_t.append(crime_station)

crime_total = pd.concat(crime_station_t)
crime_total.head()
# Out:
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_107931/2215294261.py:5: FutureWarning: The provided callable <function sum at 0x74096ebdf2e0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
#    구분   강간검거     강간  강도검거    강도  살인검거    살인   절도검거      절도    폭력머거      폭력  \
# 0  강남  124.0  168.0  33.0  65.0   6.0   5.0  461.0  1014.0  2666.0  2853.0
# 1  강동  117.0  117.0  42.0  35.0   3.0   4.0  604.0   672.0  2574.0  2619.0
# 2  강북   82.0   92.0  72.0  78.0   7.0   5.0  629.0   698.0  2416.0  2428.0
# 3  강서  117.0  137.0  40.0  43.0  15.0  16.0  710.0  1267.0  3053.0  3186.0
# 4  관악  129.0  236.0  44.0  63.0   4.0   5.0  663.0  1628.0  2960.0  3192.0
#
#    year
# 0  2006
# 1  2006
# 2  2006
# 3  2006
# 4  2006

# %%
crime_total_murder = crime_total.pivot(index='year', columns='구분', values='살인')
crime_total_murder
# Out:
# 구분      강남    강동    강북    강서    관악    광진    구로    금천  남대문    노원  ...    수서  \
# year                                                             ...
# 2000   3.0  12.0   9.0   6.0   8.0   2.0  10.0  10.0  3.0   3.0  ...   3.0
# 2001  13.0   9.0   6.0  16.0   3.0  14.0   4.0  13.0  6.0   8.0  ...   4.0
# 2002   3.0   6.0   7.0   8.0   8.0  12.0   4.0  16.0  2.0   7.0  ...   7.0
# 2003   7.0   6.0   9.0   5.0   4.0   6.0   6.0  15.0  2.0   3.0  ...   5.0
# 2004   8.0   7.0  15.0   8.0   0.0  10.0  13.0  16.0  1.0   5.0  ...   6.0
# 2005   8.0   5.0  10.0  10.0   5.0  16.0  10.0  14.0  1.0  10.0  ...   5.0
# 2006   5.0   4.0   5.0  16.0   5.0   7.0  16.0   5.0  2.0   6.0  ...   4.0
# 2007   8.0   7.0  12.0   4.0  13.0   8.0  19.0   6.0  0.0  11.0  ...   4.0
# 2008  10.0   8.0   7.0  18.0  10.0   3.0  22.0   3.0  1.0   3.0  ...   3.0
# 2009  10.0   6.0   7.0  10.0  11.0  11.0  16.0   7.0  2.0  12.0  ...   7.0
# 2010  12.0  18.0   7.0   7.0  13.0  11.0  17.0   8.0  3.0  16.0  ...   2.0
# 2011  15.0   7.0   7.0  18.0  19.0  11.0  12.0  14.0  1.0   8.0  ...   8.0
# 2012   6.0   5.0   3.0  15.0   7.0   6.0   9.0   8.0  1.0   2.0  ...   3.0
# 2013   6.0   9.0   2.0  14.0   7.0   4.0   9.0   6.0  1.0   7.0  ...   6.0
# 2014   8.0   5.0   6.0   8.0   7.0   8.0   3.0   7.0  3.0   5.0  ...   5.0
# 2015   3.0   4.0   7.0   7.0   9.0   4.0   8.0   3.0  1.0  10.0  ...  10.0
# 2016   3.0   4.0   7.0   9.0   6.0   4.0   9.0   6.0  1.0   5.0  ...   2.0
# 2017   6.0   5.0   8.0  11.0   8.0   6.0   7.0   5.0  1.0   4.0  ...   1.0
# 2018   5.0   3.0   8.0  11.0   9.0   7.0   8.0   6.0  1.0   5.0  ...   5.0
# 2019   3.0   6.0   6.0   8.0  13.0   4.0  10.0   6.0  1.0   4.0  ...   2.0
#
# 구분      양천   영등포    용산    은평   종로    종암    중랑   중부   혜화
# year
# 2000   5.0   6.0   5.0   2.0  4.0   8.0  13.0  1.0  3.0
# 2001   8.0   7.0   3.0   6.0  3.0  10.0  16.0  0.0  4.0
# 2002   6.0   3.0   2.0   3.0  0.0   5.0   8.0  1.0  4.0
# 2003   7.0   8.0  14.0   5.0  3.0   2.0  11.0  0.0  5.0
# 2004   6.0   5.0   8.0   5.0  1.0   7.0   7.0  2.0  7.0
# 2005  12.0   4.0   9.0   7.0  3.0   6.0  14.0  2.0  2.0
# 2006   5.0  12.0   9.0   3.0  7.0   6.0  11.0  4.0  5.0
# 2007   8.0  13.0   9.0   6.0  5.0   8.0  13.0  4.0  2.0
# 2008  11.0  19.0   7.0   7.0  5.0   5.0   7.0  4.0  3.0
# 2009   8.0  24.0  11.0   5.0  6.0   2.0  15.0  1.0  1.0
# 2010   9.0  34.0   9.0   4.0  5.0   6.0  13.0  5.0  2.0
# 2011   4.0  18.0  13.0  10.0  6.0   4.0  10.0  2.0  2.0
# 2012   5.0  18.0   7.0   4.0  2.0   4.0   9.0  4.0  2.0
# 2013   3.0  14.0   4.0   5.0  2.0   1.0   6.0  0.0  2.0
# 2014   5.0  14.0   1.0   5.0  3.0   2.0  11.0  3.0  0.0
# 2015   3.0  14.0   5.0   1.0  3.0   3.0  13.0  2.0  3.0
# 2016   5.0  13.0   4.0   2.0  4.0   2.0   8.0  2.0  2.0
# 2017   3.0  15.0   1.0   3.0  5.0   2.0   5.0  0.0  2.0
# 2018   2.0  17.0   1.0   4.0  5.0   6.0   4.0  1.0  1.0
# 2019   6.0  10.0   3.0   2.0  2.0   1.0  10.0  1.0  2.0
#
# [20 rows x 31 columns]

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns

plt.figure(figsize = (13, 10))
sns.heatmap(crime_total_murder,
            annot=True, linewidths=.5, cmap='RdPu')
plt.autoscale()
plt.tight_layout(pad=5)
plt.show()

# %%
crime_total_murder.plot(figsize=(12,10))
plt.show()

# %%
crime_total_murder[['강남','서초','영등포']].plot(figsize=(12,10))
plt.show()

# %%
crime_total_violence = crime_total.pivot(index='year', columns='구분', values='폭력')
crime_total_violence[['강남', '서초','영등포','노원','관악']].plot(figsize=(12,10))
plt.show()

# %%
crime_total_violence = crime_total.pivot(index='year', columns='구분', values='강간')
crime_total_violence[['강남', '서초','영등포','노원','관악']].plot(figsize=(12,10))
plt.show()
